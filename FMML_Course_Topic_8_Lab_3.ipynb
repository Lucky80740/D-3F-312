# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucky80740/IIIT-FMML-LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:33:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  61.9MB/s    in 1.1s
#
# 2024-03-26 14:33:44 (61.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25223  1506.06343v3  The purpose of mid-level visual element discov...    cs
# 2687   1706.02999v1  In this paper we explore methods to exploit sy...  stat
# 22776  1706.05136v1  We present a probabilistic framework for overl...  stat
# 11979  1705.08858v1  This paper presents the Speech Technology Cent...    cs
# 383    1707.08167v2  With the development of neural networks based ...  stat
# ...             ...                                                ...   ...
# 37443  1706.09597v1  In this paper, we introduce Path Integral Netw...    cs
# 25164  1506.02432v1  In this position paper, we consider the state ...    cs
# 33558   1008.4063v3  We present details of the analysis of the nonl...    cs
# 33368   1107.3498v1  Slow self-avoiding adaptive walks by an infini...    cs
# 28434  1706.06531v1  Breast cancer is the most prevalent cancer typ...    cs
#
#                                                    title  year  \
# 25223  Mining Mid-level Visual Patterns with Deep CNN...  2015
# 2687   Symmetry Learning for Function Approximation i...  2017
# 22776  Deep Generative Models for Relational Data wit...  2017
# 11979      Audio-replay attack detection countermeasures  2017
# 383                On The Robustness of a Neural Network  2017
# ...                                                  ...   ...
# 37443  Path Integral Networks: End-to-End Differentia...  2017
# 25164  Reflection Invariance: an important considerat...  2015
# 33558                    Nonlinear Quality of Life Index  2010
# 33368  What can we learn from slow self-avoiding adap...  2011
# 28434  A comparative study of breast surface reconstr...  2017
#
#                                                 keywords
# 25223  [discovery, representative, discriminative, pr...
# 2687   [symmetries, efficiency, reinforcement, increa...
# 22776  [probabilistic, framework, overlapping, commun...
# 11979  [technology, detection, automatic, verificatio...
# 383    [development, applications, textitblack, under...
# ...                                                  ...
# 37443  [introduce, recurrent, representation, algorit...
# 25164  [invariance, horizontal, orientation, reflecti...
# 33558  [nonlinear, countries, indicators, purchasing,...
# 33368  [algorithm, themselves, conducted, examination...
# 28434  [prevalent, generally, aesthetic, increasingly...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25223    [discovery, representative, discriminative, pr...
# 2687     [symmetries, efficiency, reinforcement, increa...
# 22776    [probabilistic, framework, overlapping, commun...
# 11979    [technology, detection, automatic, verificatio...
# 383      [development, applications, textitblack, under...
#                                ...
# 38587    [extraction, dynamical, intensity, landscape, ...
# 10766    [completion, generated, solutions, assumptions...
# 20797    [representation, knowledge, continuous, dimens...
# 2103     [introduce, variables, generalize, proposals, ...
# 21769    [nonlinear, regression, structure, hierarchica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8835 words.
# Out of those 4580 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cbbf788e-7d66-4457-9ef6-86257bb5d103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbbf788e-7d66-4457-9ef6-86257bb5d103")) {                    Plotly.newPlot(                        "cbbf788e-7d66-4457-9ef6-86257bb5d103",                        [{"x":["techniques","discovery","properties","typically","discriminative","literature","consistent","retrieved","connected","semantically","representations","surprisingly","construct","codewords","prospective","association","dictionary","representation","classification","effective","demonstrate","convolutional","outperforms","possesses","visualize","technique","appealing","extracted","representative","activations","activation","integration","popularized","experience","symmetries","attention","efficiency","introduce","significantly","classical","functional","especially","performance","utilizing","discovered","mechanism","increasing","approximation","framework","reinforcement","exploitation","information","experiments","incorporate","potential","completeness","extendable","conjugacy","attributes","qualitative","efficient","generative","conditioning","overlapping","interpretability","relational","benchmark","available","augmentation","quantitative","community","providing","regression","attractive","inference","probabilistic","facilitates","prediction","architecture","resulting","development","demonstrated","comparison","evaluation","classifier","verification","substantial","different","performed","detection","challenge","extraction","according","frameworks","conditions","technology","automatic","countermeasures","approaches","ultimately","communication","impossibility","parameters","estimated","neuromorphic","combinatorial","explosion","coefficient","configurations","assessing","capabilities","dependencies","robustness","polynomial","distributed","experimentally","lipschitz","applications","pessimistic","illustrating","theoretical","exponential","impossible","requirements","practically","understand","computing","dependency","empirical","asymptotic","environment","asynchronous","harnessed","convergence","computation","counterpart","algorithm","comparably","performing","variational","optimization","implementation","computations","interface","parallelism","guaranteeing","horizontal","extensive","stochastic","experimental","analogous","brightness","possibilities","discussion","appropriate","processing","interference","visibility","numerical","manipulation","variations","validating","generated","additionally","expressive","contemporary","difference","monophonic","generation","professional","expression","predictive","furthermore","listening","including","conditional","achieving","instances","discrimination","statistical","counterfactual","randomization","clustering","statistics","complexity","application","advantage","flexibility","introduced","nonparametric","correspondence","extensions","dependent","dirichlet","contributions","unsupervised","additional","trajectories","retrieval","illustrate"],"y":[363,58,213,97,96,128,82,10,65,42,228,41,77,3,3,31,55,369,549,257,567,367,285,9,12,236,17,116,36,21,33,47,1,39,4,159,171,337,262,104,42,120,853,48,30,106,82,90,546,128,18,666,565,47,163,17,4,0,79,50,402,132,7,21,24,25,208,309,25,62,75,81,118,24,223,135,13,236,222,127,125,94,130,254,139,32,45,751,119,347,142,126,105,35,144,60,194,2,436,8,65,1,228,55,6,39,10,25,27,16,46,49,106,51,96,54,6,456,1,2,163,40,26,53,9,71,121,55,149,17,131,11,3,115,147,11,834,6,76,47,276,126,32,29,10,3,5,170,126,372,4,8,10,32,76,288,17,5,91,25,82,7,175,61,39,16,52,2,116,4,54,60,145,4,254,107,66,89,20,139,3,4,151,66,213,238,83,32,142,18,29,39,63,27,54,137,119,38,100,86],"type":"bar"},{"x":["techniques","discovery","p ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4580,), (4580, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>the</span> <span style=''>Indus</span> <span style=''>Script</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Standardized</span> <span style=''>corpora</span> <span style=''>of</span> <span style=''>undeciphered</span> <span style=''>scripts</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33823529411764697);'>necessary</span> <span style=''>starting</span> <span style=''>point</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>epigraphy</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>laborious</span> <span style=''>human</span> <span style=''>effort</span> <span style=''>for</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>preparation</span> <span style=''>from</span> <span style=''>raw</span> <span style=''>archaeological</span> <span style=''>records</span> <span style='background-color:rgba(0, 255, 0, 0.368421052631579);'>Automating</span> <span style=''>this</span> <span style=''>process</span> <span style=''>through</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>be</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.36043360433604354);'>significant</span> <span style=''>aid</span> <span style=''>to</span> <span style=''>epigraphical</span> <span style=''>research</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>take</span> <span style=''>the</span> <span style=''>first</span> <span style=''>steps</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>and</span> <span style=''>present</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>pipeline</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>as</span> <span style=''>input</span> <span style=''>images</span> <span style=''>of</span> <span style=''>the</span> <span style=''>undeciphered</span> <span style=''>Indus</span> <span style=''>script</span> <span style=''>as</span> <span style=''>found</span> <span style=''>in</span> <span style=''>archaeological</span> <span style='background-color:rgba(0, 255, 0, 0.44000000000000006);'>artifacts</span> <span style=''>and</span> <span style=''>returns</span> <span style=''>as</span> <span style=''>output</span> <span style=''>a</span> <span style=''>string</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>graphemes</span> <span style=''>suitable</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inclusion</span> <span style=''>in</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>corpus</span> <span style=''>The</span> <span style=''>image</span> <span style=''>is</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposed</span> <span style=''>into</span> <span style=''>regions</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521735);'>Selective</span> <span style=''>Search</span> <span style=''>and</span> <span style=''>these</span> <span style=''>regions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>classified</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.34146341463414637);'>containing</span> <span style=''>textual</span> <span style=''>andor</span> <span style='background-color:rgba(255, 0, 0, 0.34482758620689646);'>graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>informatio ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Initialising</span> <span style=''>Kernel</span> <span style=''>Adaptive</span> <span style=''>Filters</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>both</span> <span style=''>(i)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determining</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>settings</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>adaptive</span> <span style=''>filters</span> <span style=''>(KAFs)</span> <span style=''>and</span> <span style=''>(ii)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>fully</span> <span style=''>adaptive</span> <span style=''>KAFs</span> <span style=''>whereby</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>weights</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionaries</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>learnt</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style=''>This</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>and</span> <span style=''>defining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dedicated</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>the</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>weights</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enforcing</span> <span style=''>desired</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sparsity</span> <span style=''>The</span> <span style=''>model</span> <span style=''>can</span> <span style=''>then</span> <span style=''>be</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>data</span> <span style=''>to</span> <span style=''>initialise</span> <span style=''>standard</span> <span style=''>KAFs</span> <span style=''>or</span> <span style=''>updated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style=''>each</span> <span style=''>time</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>becomes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nonlinearnon</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>learning</span> <span style=''>and</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4328358208955224);'>Contextual</span> <span style=''>Bandits</span> <span style=''>with</span> <span style=''>Latent</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>Confounders</span> <span style=''>An</span> <span style=''>NMF</span> <span style=''>Approach</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3636363636363636);'>advertising</span> <span style=''>systems</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.38536585365853654);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.4328358208955224);'>contextual</span> <span style=''>bandits</span> <span style=''>with</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.32517482517482516);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>confounder</span> <span style=''>In</span> <span style=''>our</span> <span style=''>model</span> <span style=''>there</span> <span style=''>are</span> <span style=''>L</span> <span style=''>observed</span> <span style=''>contexts</span> <span style=''>and</span> <span style=''>K</span> <span style=''>arms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>bandit</span> <span style=''>The</span> <span style=''>observed</span> <span style=''>context</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influences</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>obtained</span> <span style=''>through</span> <span style=''>a</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>confounder</span> <span style=''>variable</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinality</span> <span style=''>m</span> <span style=''>(m</span> <span style=''>ll</span> <span style=''>LK)</span> <span style=''>The</span> <span style=''>arm</span> <span style=''>choice</span> <span style=''>and</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>confounder</span> <span style=''>causally</span> <span style='background-color:rgba(0, 255, 0, 0.41935483870967744);'>determines</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>while</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>context</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>confounder</span> <span style=''>Under</span> <span style=''>this</span> <span style=''>model</span> <span style=''>the</span> <span style=''>L</span> <span style=''>times</span> <span style=''>K</span> <span style=''>mean</span> <span style=''>reward</span> <span style=''>matrix</span> <span style=''>mathbfU</span> <span style=''>(for</span> <span style=''>each</span> <span style=''>context</span> <span style=''>in</span> <span style=''>L</span> <span style=''>and</span> <span style=''>each</span> <span style=''>arm</span> <span style=''>in</span> <span style=''>K)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorizes</span> <span style=''>into</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>factors</span> <span style=''>mathbfA</span> <span style=''>(L</span> <span style=''>times</span> <span style=''>m)</span> <span style=''>and</span> <span style=''>mathbfW</span> <span style=''>(m</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Batch</span> <span style=''>Policy</span> <span style=''>Gradient</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conversation</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>chatbots</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>when</span> <span style=''>the</span> <span style=''>rewards</span> <span style=''>are</span> <span style=''>noisy</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>For</span> <span style=''>instance</span> <span style=''>a</span> <span style=''>chatbot</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style=''>customer</span> <span style=''>service</span> <span style=''>support</span> <span style=''>can</span> <span style=''>be</span> <span style=''>scored</span> <span style=''>by</span> <span style=''>quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assurance</span> <span style=''>agents</span> <span style=''>but</span> <span style=''>this</span> <span style=''>process</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>and</span> <span style=''>noisy</span> <span style=''>Previous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>work</span> <span style=''>for</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>uses</span> <span style=''>on</span> <span style=''>policy</span> <span style=''>updates</span> <span style=''>andor</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>on</span> <span style=''>line</span> <span style=''>learning</span> <span style=''>settings</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>that</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>for</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>develop</span> <span style=''>an</span> <span style=''>off</span> <span style=''>policy</span> <span style=''>batch</span> <span style=''>policy</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>(BPG)</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>efficacy</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>via</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>and</span> <span style=''>an</span> <span style=''>Amazon</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23811226313907757)
# 	architecture (0.07937075437969253)
# 	knowledge (0.1262066499821237)
# 	processing (0.10296746514122274)
# 	segmentation (0.07400786557025385)
# 	experimental (0.13299964247407936)
# 	detection (0.12406149445834823)
# 	different (0.26850196639256346)
# 	convolutional (0.13121201287093315)
# 	recognition (0.13121201287093315)
#
# Some Statistics words are:
# 	optimization (0.18771842236645034)
# 	theoretical (0.1492760858711932)
# 	variables (0.14028956565152273)
# 	stochastic (0.1417873190214678)
# 	statistical (0.15227159261108336)
# 	estimation (0.17423864203694459)
# 	distribution (0.18622066899650525)
# 	dimensional (0.1892161757363954)
# 	inference (0.2071892161757364)
# 	regression (0.1872191712431353)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="369b2d16-eb3d-430b-8119-c8bc01ca93e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("369b2d16-eb3d-430b-8119-c8bc01ca93e9")) {                    Plotly.newPlot(                        "369b2d16-eb3d-430b-8119-c8bc01ca93e9",                        [{"x":["techniques","discovery","properties","typically","discriminative","literature","consistent","retrieved","connected","semantically","representations","surprisingly","construct","codewords","prospective","association","dictionary","representation","classification","effective","demonstrate","convolutional","outperforms","possesses","visualize","technique","appealing","extracted","representative","activations","activation","integration","popularized","experience","symmetries","attention","efficiency","introduce","significantly","classical","functional","especially","performance","utilizing","discovered","mechanism","increasing","approximation","framework","reinforcement","exploitation","information","experiments","incorporate","potential","completeness","extendable","conjugacy","attributes","qualitative","efficient","generative","conditioning","overlapping","interpretability","relational","benchmark","available","augmentation","quantitative","community","providing","regression","attractive","inference","probabilistic","facilitates","prediction","architecture","resulting","development","demonstrated","comparison","evaluation","classifier","verification","substantial","different","performed","detection","challenge","extraction","according","frameworks","conditions","technology","automatic","countermeasures","approaches","ultimately","communication","impossibility","parameters","estimated","neuromorphic","combinatorial","explosion","coefficient","configurations","assessing","capabilities","dependencies","robustness","polynomial","distributed","experimentally","lipschitz","applications","pessimistic","illustrating","theoretical","exponential","impossible","requirements","practically","understand","computing","dependency","empirical","asymptotic","environment","asynchronous","harnessed","convergence","computation","counterpart","algorithm","comparably","performing","variational","optimization","implementation","computations","interface","parallelism","guaranteeing","horizontal","extensive","stochastic","experimental","analogous","brightness","possibilities","discussion","appropriate","processing","interference","visibility","numerical","manipulation","variations","validating","generated","additionally","expressive","contemporary","difference","monophonic","generation","professional","expression","predictive","furthermore","listening","including","conditional","achieving","instances","discrimination","statistical","counterfactual","randomization","clustering","statistics","complexity","application","advantage","flexibility","introduced","nonparametric","correspondence","extensions","dependent","dirichlet","contributions","unsupervised","additional","trajectories","retrieval","illustrate","distribution","recognition","modulation","relationship","autoencoders","communications","structured","functions","recognize","observation","correlation","principle","capturing","structure","effectiveness","procedures","intrinsic","relationships","implemented","adaptively","motivated","important","structures","estimation","effectively","challenging","therefore","procedure","measurement","difficult","underlying","physiological","superposition","responses","synthetic","compressed","decomposition","components","unfortunately","undesired","hypotheses","necessary","condition","universally","measurable","compactness","separable","subspaces","guaranteed","measurability","learnability","compression"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	conjugacy
# 	measurability
# 	prescribe
# 	recidivism
# 	disagreements
# 	unbalanced
# 	multiplayer
# 	subroutines
# 	cumulants
# 	discharge
# 	certifiable
# 	epidemics
# 	sparsistent
# 	propensity
# 	searchlight
# 	integrand
# 	resamples
# 	regressions
# 	tractably
# 	convexification
# Some words which never appear in Statistics papers:
# 	codewords
# 	countermeasures
# 	visibility
# 	manipulation
# 	monophonic
# 	listening
# 	summarizers
# 	rethinking
# 	emphasizes
# 	enclosing
# 	singularity
# 	syntactic
# 	discontinuities
# 	superresolution
# 	compilation
# 	grammatical
# 	transmitted
# 	downsampling
# 	multiplicity
# 	discourse

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0721966205837174e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
